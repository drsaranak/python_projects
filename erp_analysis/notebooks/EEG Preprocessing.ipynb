# %%
import mne 
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install 'mne[brainvision]'
# Out:
# ...
# WARNING: mne 1.9.0 does not provide the extra 'brainvision'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Update this path to match your actual file location
raw = mne.io.read_raw_brainvision("/Users/saranajay/Library/CloudStorage/OneDrive-Personal/Physiology AIIMS Patna/Thesis Related/Data Collection/Thesis Data till 404013/Brain Vision/Saran/40HzBBDepression0001b.vhdr", preload=True)
# Out:
# Extracting parameters from /Users/saranajay/Library/CloudStorage/OneDrive-Personal/Physiology AIIMS Patna/Thesis Related/Data Collection/Thesis Data till 404013/Brain Vision/Saran/40HzBBDepression0001b.vhdr...
# Setting channel info structure...
# Reading 0 ... 1204739  =      0.000 ...  1204.739 secs...

# %%
# %pip install mne PyQt5
# %matplotlib inline
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
raw.plot(duration=10.0, title='Raw EEG', show_scrollbars=True)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.info
print (raw.info['nchan'])
# Out:
# 31

# %%
# !pip install scipy==1.6.0
# Out:
# ...
#   Using cached scipy-1.6.0.tar.gz (27.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for scipy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [889 lines of output]
#       setup.py:563: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.core import setup
#       Running from SciPy source directory.
#       INFO: lapack_opt_info:
#       INFO: lapack_armpl_info:
# ...

# %%
raw.filter(0.1, 40.0)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 33001 samples (33.001 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.5s finished
# <RawBrainVision | 40HzBBDepression0001b.eeg, 31 x 1204740 (1204.7 s), ~285.0 MiB, data loaded>
